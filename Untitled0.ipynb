# %% [markdown]
# <a href="https://colab.research.google.com/github/Udaythecoder/CT_TASK-02/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

marks=[90,85,87,76,59,37,69,71]
shr=[1,3,2,5,4,3,2,5]

print("mean: ",np.mean(marks))
print("median: ",np.median(marks))
print("variance: ",np.var(marks))
print("standard deviation: ",np.std(marks))
print("correlation: ",np.corrcoef(marks))
# Out:
# mean:  71.75
# median:  73.5
# variance:  267.1875
# standard deviation:  16.345871038277526
# correlation:  1.0

# %%
import matplotlib.pyplot as plt
marks=[90,85,87,76,59,37,69,71]
shr=[1,3,2,5,4,3,2,5]
plt.plot(marks,shr)
plt.show()

# %%
import matplotlib.pyplot as plt

months = ['Jan','Feb', 'Mar', 'Apr', 'May', 'Jun']
sales = [10, 15, 13, 18, 22, 25]

plt.figure(figsize=(8, 5))
plt.plot(months, sales, marker='o', color='b', linestyle='-', linewidth=2)

plt.title('Monthly Sales Trend', fontsize=14, fontweight='bold')
plt.xlabel('Month', fontsize=12)
plt.ylabel('Sales (in $1,000s)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)

plt.show()
